# %% [markdown]
# # 验证星形图生成脚本

# %%
import os, sys
sys.path.append(r'c:/Users/Fa render2/Desktop/20260707_StarModelCreation')
import star_model_generator as smg
res = smg.batch_generate_star_charts(
    file_path='TestData/工作簿3.xlsx',
    output_folder='星形图输出',
)
print(res)
print('exists', os.path.exists(r'c:/Users/Fa render2/Desktop/20260707_StarModelCreation/星形图输出/星形图维度得分汇总.xlsx'))
print('files', os.listdir(r'c:/Users/Fa render2/Desktop/20260707_StarModelCreation/星形图输出'))
